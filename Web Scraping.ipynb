# %%
from requests import get
from requests.exceptions import RequestException
from contextlib import closing
from bs4 import BeautifulSoup
import pandas as pd

# %%
def simple_get(url):
    """
    Attempts to get the content at `url` by making an HTTP GET request.
    If the content-type of response is some kind of HTML/XML, return the
    text content, otherwise return None.
    """
    try:
        with closing(get(url, stream=True)) as resp:
            if is_good_response(resp):
                return resp.content
            else:
                return None

    except RequestException as e:
        log_error('Error during requests to {0} : {1}'.format(url, str(e)))
        return None


def is_good_response(resp):
    """
    Returns True if the response seems to be HTML, False otherwise.
    """
    content_type = resp.headers['Content-Type'].lower()
    return (resp.status_code == 200 
            and content_type is not None 
            and content_type.find('html') > -1)


def log_error(e):
    """
    It is always a good idea to log errors. 
    This function just prints them, but you can
    make it do anything.
    """
    print(e)

# %%
raw_html = simple_get('https://realpython.com/blog/')
len(raw_html)
# Out:
# 540714

# %%
raw_html
# Out:
# b'\n<!doctype html>\n<html lang="en">\n<head>\n<link href="//files.realpython.com" rel="dns-prefetch">\n<link href="//fonts.googleapis.com" rel="dns-prefetch">\n<link href="//fonts.gstatic.com" rel="dns-prefetch">\n<title>Python Tutorials \xe2\x80\x93 Real Python</title>\n<meta name="author" content="Real Python">\n<meta name="description" content="Learn Python online: Python tutorials for developers of all skill levels, Python books and courses, Python news, code examples, articles, and more.">\n<meta name="keywords" content="">\n<meta charset="utf-8">\n<meta name="viewport" content="width=device-width, initial-scale=1, shrink-to-fit=no">\n<link rel="canonical" href="https://realpython.com/">\n<meta name="twitter:card" content="summary">\n<meta property="twitter:image" content="https://realpython.com/static/social-default-image.5e1aa4786b3a.png">\n<meta property="og:image" content="https://realpython.com/static/social-default-image.5e1aa4786b3a.png">\n<meta name="twitter:creator" co
# ...

# %%
raw_html = open('C:\\Users\\Suman Saurav\\Downloads\\index.html').read()
html = BeautifulSoup(raw_html, 'html.parser')
for p in html.select('h4'):
         print(p.text)
# Out:
# Name: ABHISHEK KUMAR
# Resume tagging using CRF
# Supply Chain Analytics using twitter Data Analytics
# Automated marketing research using online customer reviews
# Name: AISHWARYA VERMA
# Restaurant Database Management
# University Feedback Analysis
# Information extraction
# Vehicle routing scheduling for cross-docking in the supply chain
# Name: ANKIT SINGH
# Summer Research Intern (Neev advisory )
# Fake news prediction using NLP
# Auto tagging online contents
# Demand forecasting using deep learning and time series
# Name: ANURAG SHARMA
# Customers churn prediction and market retention using support vector machines
# Resilient supplier selection using supervised machine learning algorithms in supply chain analytics
# Predicting success of bank telemarketing calls using different classification algorithms
# Statistical analysis of university survey data using R
# Name: ATUL JOSHI
# Android Development at Mrityunjay Innovations, Delhi
# ...

# %%
for p in html.findAll('p',attrs = {'class':'desc'}):
    print(p.text)
# Out:
# Using Conditional Random Feilds key informations such as Name,DOB,Gender,etc are tagged so that it can be used for automated online form filling and resume filtering
# Issues in the supply chain are discovered using the Sentimental anlysis then clustering of tweets of consumer about a particular product.
# Using clustering important attribues are found to be marketed by the companies and using Correspondence Analysis Market strucutre is determined for different brands of that products.
# Built a Database Management System to keep customer acccounts and employee records.
# This survey represents the total 467 studentsâ€™ responses of university feedback forms. The main purpose of this project to analyze feedback data and read the trends between the quantity we have chosen.
# This project is based on machine learning. I am using Conditional Random Field for the automation of online form filling
# ...

# %% [markdown]
# # Getting images of all profiles

# %%
for p in html.select('img'):
    print(p)
# Out:
# <img id="logo" src="mypic.jpg"/>
# <img alt="pic" src="ab.jpg"/>
# <img alt="pic" src="IMG-20190825-WA0012.jpg"/>
# <img alt="pic" src="ANKIT.jpg"/>
# <img alt="pic" src="anurag 02.jpg"/>
# <img alt="pic" src="Photo (1).jpg"/>
# <img alt="pic" src="DSC_0160 (1).jpg"/>
# <img alt="pic" src="photo.jpg"/>
# <img alt="pic" src="2018MSBDA008.jpg"/>
# <img alt="pic" src="IMG_20190824_201816.jpg"/>
# <img alt="pic" src="Ipsita.jpeg"/>
# <img alt="pic" src="DSC_0127(3).jpg"/>
# <img alt="pic" src="AirBrush_20190825222927.jpg"/>
# <img alt="pic" src="DSC_0015-01.jpeg"/>
# <img alt="pic" src="DSC_0047(1).jpg"/>
# <img alt="pic" src="divya1.jpg"/>
# <img alt="pic" src="sumit.jpg"/>
# <img alt="pic" src="20190323_061721-1 (1)_opt.jpg"/>
# <img alt="pic" src="bimal.jpg"/>

# %%
names = []
projects = []

# %% [markdown]
# # Getting names of all profiles

# %%
for p in html.findAll('div',attrs ={'class':'info'}):
    names.append(p.text.strip()[6:])
names
# Out:
# ['ABHISHEK KUMAR',
#  'AISHWARYA VERMA',
#  'ANKIT SINGH',
#  'ANURAG SHARMA',
#  'ATUL JOSHI',
#  'PAWAN BISHT',
#  'NITESH SUKHWANI',
#  'ABHISHEK CHAND',
#  'ANAMIKA ANURAG',
#  'IPSITA PATNAIK',
#  'SUMAN SAURAV',
#  'ARKAPRABHA MAJUMDAR',
#  'PRADYUMNA KUMAR SAHOO',
#  'PRIYA SINHA',
#  'DIVYA KUMARI',
#  'SUMIT KUMAR',
#  'VIVEK SHUKLA',
#  'BIMAL KUMAR']

# %% [markdown]
# # Getting projects of all profiles

# %%
for p in html.findAll('div',attrs = {'class':'project'}):
    for h in p.findAll('h4'):
        projects.append(h.text)
projects
# Out:
# ['Resume tagging using CRF',
#  'Supply Chain Analytics using twitter Data Analytics',
#  'Automated marketing research using online customer reviews',
#  'Restaurant Database Management',
#  'University Feedback Analysis',
#  'Information extraction',
#  'Vehicle routing scheduling for cross-docking in the supply chain',
#  'Summer Research Intern (Neev advisory )',
#  'Fake news prediction using NLP',
#  'Auto tagging online contents  ',
#  'Demand forecasting using deep learning and time series',
#  'Customers churn prediction and market retention using support vector machines',
#  'Resilient supplier selection using supervised machine learning algorithms in supply chain analytics',
#  'Predicting success of bank telemarketing calls using different classification algorithms',
#  'Statistical analysis of university survey data using R',
#  'Android Development at Mrityunjay Innovations, Delhi',
#  'Bank Telemarketing Success Prediction using Machine Learning',
# ...

# %%
df = pd.DataFrame({'Names':names})
df
# Out:
#                     Names
# 0          ABHISHEK KUMAR
# 1         AISHWARYA VERMA
# 2             ANKIT SINGH
# 3           ANURAG SHARMA
# 4              ATUL JOSHI
# 5             PAWAN BISHT
# 6         NITESH SUKHWANI
# 7          ABHISHEK CHAND
# 8          ANAMIKA ANURAG
# 9          IPSITA PATNAIK
# 10           SUMAN SAURAV
# 11    ARKAPRABHA MAJUMDAR
# 12  PRADYUMNA KUMAR SAHOO
# 13            PRIYA SINHA
# 14           DIVYA KUMARI
# 15            SUMIT KUMAR
# 16           VIVEK SHUKLA
# 17            BIMAL KUMAR

# %%
html.select('h1')[1]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-12-6db078ad80d5> in <module>()
# ----> 1 html.select('h1')[1]
#
# IndexError: list index out of range

# %%
for i in html.select('h1'):
    if i['id'] == "2":
        print(i.text)

# %%
for i in html.select('h2'):
    print(i['class'])

# %%
for i in html.select('h1'):
    print(i['id'])
